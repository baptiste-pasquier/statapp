# %% [markdown]
# # XGBoost

# %%
import os
os.chdir(os.path.dirname(os.getcwd()))
import json
import random
import time

import matplotlib.pyplot as plt
import pandas as pd
from imblearn.over_sampling import SMOTENC, RandomOverSampler
from imblearn.pipeline import Pipeline as Pipeline_imb
from sklearn.model_selection import ParameterGrid
from tqdm.notebook import trange
from xgboost import XGBClassifier

from tools import (Modelisation, SearchCV, best_score_CV, datasets,
                   graph_2scores_CV, graph_2scores_CV_comp, graph_3scores_CV,
                   graph_param_CV, restauration_CV, PDF)

pdf = PDF('output/model_xgboost/')

t = time.time()

# %%
df = pd.read_csv('data/df_train_prepro.csv').sample(frac=1)
df.shape
# Out:
# (1610494, 48)

# %% [markdown]
# **Définition des variables quantitatives, des variables catégorielles et des datasets :**

# %%
datasets_df = datasets(df)
X_quant = datasets_df['X_quant']
X_cat = datasets_df['X_cat']
X = datasets_df['X']
y = datasets_df['y']
# Out:
# Columns_quant : default
# Columns_cat : default
# drop : if_binary
#
# Nombre de variables pour X_quant : 13
# Index(['contextid', 'campaignctrlast24h', 'dayssincelastvisitdouble',
#        'ltf_nbglobaldisplay_4w', 'ltf_nbpartnerdisplayssincelastclick',
#        'ltf_nbpartnerdisplay_90d', 'ltf_nbpartnerclick_90d',
#        'ltf_nbpartnersales_90d', 'nbdayssincelastclick', 'nbdisplay_1hour',
#        'nbdisplayglobalapprox_1d_sum_xdevice', 'display_size',
#        'zonecostineuro'],
#       dtype='object')
# Nombre de variables pour X_cat : 56
# Index(['display_env_app_android', 'display_env_app_ios', 'display_env_other',
#        'display_env_web', 'target_env_2', 'campaignscenario_0',
#        'campaignscenario_5', 'campaignscenario_6', 'campaignscenario_11',
#        'campaignscenario_12', 'campaignscenario_13', 'campaignscenario_17',
#        'campaignvertical_14.0', 'campaignvertical_20.0',
#        'campaignvertical_23.0', 'campaignvertical_129.0',
#        'campaignvertical_200002.0', 'is_interstitial_True',
#        'device_type_Android', 'device_type_Desktop',
#        'device_type_Desktop - Safari', 'device_type_Mobile - Other',
#        'device_type_Unknown', 'device_type_iPad', 'device_type_iPhone',
#        'hour_0', 'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6',
#        'hour_7', 'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12',
#        'hour_13', 'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18',
#        'hour_19', 'hour_20', 'hour_21', 'hour_22', 'hour_23', 'weekday_Friday',
#        'weekday_Monday', 'weekday_Saturday', 'weekday_Sunday',
#        'weekday_Thursday', 'weekday_Tuesday', 'weekday_Wednesday'],
#       dtype='object')
# Nombre de variables pour X : 69

# %%
len(y[y == 0]) / (len(y[y == 1]))
# Out:
# 16.529395045803362

# %% [markdown]
# ## 1. Modèle brut
# ### 1.1. Variables quantitatives

# %%
m = Modelisation(X_quant, y, XGBClassifier(n_jobs=-1))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()
# Out:
# Export PDF : output/model_xgboost/00.pdf
# f1 : 0.1363
# f3 : 0.0840
# f5 : 0.0793
# recall : 0.0767
# negative predictive value : 0.9469
# precision : 0.6132
# roc_auc : 0.8260
# training time : 21.505s
# prediction time : 0.143s

# %%
m.show_ROC(pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/01.pdf

# %%
m.plot_importance()

# %% [markdown]
# Affichage d'un arbre (par défaut le premier parmi les autres) :

# %%
m.show_graph()

# %% [markdown]
# ### 1.2. Variables catégorielles

# %%
m = Modelisation(X_cat, y, XGBClassifier(n_jobs=-1))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()
# Out:
# Export PDF : output/model_xgboost/02.pdf
# f1 : 0.0429
# f3 : 0.0246
# f5 : 0.0231
# recall : 0.0222
# negative predictive value : 0.9441
# precision : 0.5899
# roc_auc : 0.6939
# training time : 19.322s
# prediction time : 0.25s

# %%
m.show_ROC(pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/03.pdf

# %%
fig, ax = plt.subplots(figsize=(10, 8))
m.plot_importance(ax=ax)

# %%
m.show_graph()

# %% [markdown]
# ### 1.3. Variables quantitatives + catégorielles

# %%
m = Modelisation(X, y, XGBClassifier(n_jobs=-1))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()
# Out:
# Export PDF : output/model_xgboost/04.pdf
# f1 : 0.1563
# f3 : 0.0979
# f5 : 0.0926
# recall : 0.0895
# negative predictive value : 0.9476
# precision : 0.6169
# roc_auc : 0.8339
# training time : 26.685s
# prediction time : 0.426s

# %%
m.show_ROC(pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/05.pdf

# %%
fig, ax = plt.subplots(figsize=(8, 6))
m.plot_importance(ax=ax)

# %%
m.show_graph()

# %% [markdown]
# ## 2. Tuning des hyperparamètres avec GridSearchCV
#
# On calcule le GridSearchCV sur un dataset plus petit pour avoir un temps de calcul raisonnable.

# %% [markdown]
# ### 2.1. Calcul et sauvegarde
#
# https://xgboost.readthedocs.io/en/latest/python/python_api.html#module-xgboost.sklearn

# %%
model = XGBClassifier(booster='gbtree', objective='binary:logistic', n_jobs=1)

cv_params = {
    "n_estimators": [50, 100, 150, 200, 300],
    "max_depth": [2, 4, 6, 8, 10],
    "learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
    "gamma": [0.5, 1, 1.5, 2, 5],
    "min_child_weight": [1, 3, 5, 10],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
    "scale_pos_weight": [1, 16.5]   # A typical value to consider: sum(negative instances) / sum(positive instances)
}

print(len(ParameterGrid(cv_params)))
# Out:
# 54000

# %%
# SearchCV(model, cv_params, data_frac=0.02, random=True, n_iter=10000, random_state=1234, n_jobs=35)

# %% [markdown]
# ### 2.2. Restauration des résultats

# %%
dico, results = restauration_CV('XGBoost_CV_Randomized10000_54000_0.02')
# Out:
# model : XGBClassifier()
# model_name : XGBoost
# type : RandomizedSearchCV
# len_grid : 54000
# n_iter : 10000
# columns_quant : default
# columns_cat : default
# drop : if_binary
# data_frac : 0.02
# n_jobs : 28
# temps : 9h, 49min, 35.958s
# params : {'n_estimators': [50, 100, 150, 200, 300], 'max_depth': [2, 4, 6, 8, 10], 'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3], 'gamma': [0.5, 1, 1.5, 2, 5], 'min_child_weight': [1, 3, 5, 10], 'subsample': [0.6, 0.8, 1.0], 'colsample_bytree': [0.6, 0.8, 1.0], 'scale_pos_weight': [1, 16.5]}
# scoring : {'recall': 'recall', 'precision': 'precision', 'f1': 'f1', 'f3': make_scorer(fbeta_score, beta=3), 'f5': make_scorer(fbeta_score, beta=5)}

# %%
results.head(10)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       4.827892      0.485978         0.056521         0.01461
# 1       6.217045      0.546666          0.06384        0.014702
# 2        5.76341      0.448612         0.082531        0.008073
# 3       5.272107      0.394883         0.059865        0.010045
# 4      27.123333      3.550873         0.141858        0.029233
# 5      21.790071      3.194074         0.149382        0.022937
# 6      16.884236      2.651525         0.102352        0.013627
# 7      36.681679      3.697563         0.312074        0.035006
# 8      24.234646      3.449696         0.153731        0.003391
# 9        5.92874      0.902768         0.049025        0.005734
#
#    param_subsample  param_scale_pos_weight  param_n_estimators  \
# 0              1.0                     1.0                 150
# 1              0.6                    16.5                 150
# 2              1.0                     1.0                  50
# 3              1.0                     1.0                 200
# 4              0.8                     1.0                 300
# 5              0.6                    16.5                 100
# 6              0.6                     1.0                 150
# 7              1.0                    16.5                 200
# 8              0.8                    16.5                 300
# 9              0.6                    16.5                 100
#
#    param_min_child_weight  param_max_depth  param_learning_rate  ...  \
# 0                       1                2                  0.1  ...
# 1                       3                2                 0.01  ...
# 2                       5                8                  0.1  ...
# 3                       5                2                  0.1  ...
# 4                       1                4                 0.01  ...
# 5                       5               10                 0.01  ...
# 6                      10                6                  0.3  ...
# 7                       3               10                 0.01  ...
# 8                      10                4                0.001  ...
# 9                       1                2                 0.01  ...
#
#    rank_test_precision  mean_test_f1 std_test_f1  rank_test_f1  mean_test_f3  \
# 0                 2118      0.173507    0.010928          7455      0.111013
# 1                 8937      0.237898     0.00336          4431      0.505153
# 2                 1347      0.181085    0.017622          7345      0.116266
# 3                 1526      0.188802    0.018389          7223      0.122042
# 4                  487      0.136414    0.011146          8204      0.083752
# 5                 5658      0.307231    0.008899           222      0.443871
# 6                 4234      0.205529    0.023743          6052      0.143836
# 7                 5907      0.293811    0.008446           822      0.433293
# 8                 8665      0.246772     0.00259          4170      0.513709
# 9                 9151      0.229306    0.004694          4667      0.496993
#
#    std_test_f3  rank_test_f3  mean_test_f5  std_test_f5  rank_test_f5
# 0      0.00851          7476      0.105186     0.008197          7476
# 1     0.006016          1722      0.610761     0.008963          1035
# 2     0.013744          7365      0.110204     0.013253          7369
# 3     0.014409          7251      0.115751     0.013895          7252
# 4     0.007923          8248      0.079058     0.007574          8248
# 5     0.014732          3597      0.476508     0.016749          3646
# 6     0.018945          5569      0.137497     0.018356          5540
# 7     0.014779          3756      0.467552     0.018105          3713
# 8     0.005307          1053      0.616303     0.007861           695
# 9     0.010158          1997      0.605877     0.014249          1312
#
# [10 rows x 28 columns]

# %% [markdown]
# **Graphiques XY avec 2 scores**

# %%
graph_2scores_CV(dico, results, 'recall', 'f1', s=1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/06.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'f1', s=20, zoom=0.1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/07.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'f3', s=1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/08.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'f5', s=1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/09.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'precision', s=1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/10.pdf

# %% [markdown]
# **Graphique 3D avec 3 scores**

# %%
graph_3scores_CV(dico, results, 'recall', 'precision', 'f1', s=0.1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/11.pdf

# %%
graph_3scores_CV(dico, results, 'f1', 'f3', 'f5', s=0.1, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/12.pdf

# %% [markdown]
# **Graphiques de l'effet des paramètres**

# %%
graph_param_CV(dico, results, ncols=2, height=3.5, width=6, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/13.pdf

# %% [markdown]
# **Paramètres donnant le meilleur score**

# %%
best_params = best_score_CV(dico, results, 'f3')
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1786       2.177735      0.316086         0.043524        0.006392
# 9619       1.948347      0.311994         0.039173        0.007207
# 4590       2.918276      0.381343         0.046433        0.005108
# 2622       2.734598      0.278516         0.042965        0.004356
# 6419       2.543272      0.390858         0.040283        0.008674
# 3050       5.892171      0.894119         0.063747        0.008351
# 4779       4.800132      0.706802         0.046777        0.008196
# 5075       2.705224      0.426299         0.040825        0.007048
# 9179        8.32296      1.062013         0.063236        0.007978
# 5608       4.577389      0.915383         0.062209        0.011874
#
#       param_subsample  param_scale_pos_weight  param_n_estimators  \
# 1786              1.0                    16.5                  50
# 9619              1.0                    16.5                  50
# 4590              1.0                    16.5                  50
# 2622              1.0                    16.5                  50
# 6419              1.0                    16.5                  50
# 3050              1.0                    16.5                 150
# 4779              1.0                    16.5                 100
# 5075              1.0                    16.5                  50
# 9179              0.6                    16.5                 150
# 5608              1.0                    16.5                 150
#
#       param_min_child_weight  param_max_depth  param_learning_rate  ...  \
# 1786                       5                2                  0.2  ...
# 9619                       5                2                  0.2  ...
# 4590                       3                2                  0.2  ...
# 2622                       3                2                  0.2  ...
# 6419                       5                2                  0.2  ...
# 3050                      10                2                  0.1  ...
# 4779                       3                2                  0.2  ...
# 5075                       1                2                  0.2  ...
# 9179                       1                2                  0.1  ...
# 5608                       3                2                  0.1  ...
#
#       rank_test_precision  mean_test_f1 std_test_f1  rank_test_f1  \
# 1786                 7965      0.262824    0.006993          3228
# 9619                 7965      0.262824    0.006993          3228
# 4590                 7953      0.262904    0.009571          3213
# 2622                 7953      0.262904    0.009571          3213
# 6419                 7955      0.262903    0.009563          3215
# 3050                 7805      0.264559    0.009273          3023
# 4779                 7754      0.265165    0.009542          2967
# 5075                 7976      0.262674    0.009712          3248
# 9179                 7949      0.262926    0.006974          3211
# 5608                 7893      0.263513    0.010941          3138
#
#       mean_test_f3  std_test_f3  rank_test_f3  mean_test_f5  std_test_f5  \
# 1786      0.537922     0.012306             1      0.641186     0.014037
# 9619      0.537922     0.012306             1      0.641186     0.014037
# 4590      0.537715     0.014012             3      0.640807     0.014608
# 2622      0.537715     0.014012             3      0.640807     0.014608
# 6419      0.537714     0.013999             5      0.640807     0.014599
# 3050      0.537688     0.015505             6      0.639244     0.017332
# 4779       0.53768     0.012864             7      0.638714     0.012758
# 5075      0.537522     0.014365             8      0.640701     0.015075
# 9179      0.537514     0.009425             9      0.640439     0.009266
# 5608      0.537296     0.018022            10      0.639549     0.019763
#
#       rank_test_f5
# 1786             3
# 9619             3
# 4590             5
# 2622             5
# 6419             7
# 3050            31
# 4779            37
# 5075             8
# 9179            12
# 5608            29
#
# [10 rows x 28 columns]
# Meilleure combinaison de paramètres pour f3 :
# {'subsample': 1.0,
#  'scale_pos_weight': 16.5,
#  'n_estimators': 50,
#  'min_child_weight': 5,
#  'max_depth': 2,
#  'learning_rate': 0.2,
#  'gamma': 0.5,
#  'colsample_bytree': 0.8}

# %%
best_params['booster'] = 'gbtree'
best_params['objective'] = 'binary:logistic'
best_params['n_jobs'] = -1
best_params['n_estimators'] = 100
PARAMS = {}
PARAMS[dico['model_name']] = best_params

# %% [markdown]
# **Analyse sur la base complète**

# %%
m = Modelisation(X, y, XGBClassifier(**best_params))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()

SCORES = []
metrics = m.metrics_score
metrics['model_name'] = dico['model_name']
metrics['training_time'] = m.training_time
metrics['prediction_time'] = m.prediction_time
SCORES.append(metrics)
# Out:
# Export PDF : output/model_xgboost/14.pdf
# f1 : 0.2667
# f3 : 0.5459
# f5 : 0.6508
# recall : 0.7395
# negative predictive value : 0.9799
# precision : 0.1627
# roc_auc : 0.8346
# training time : 18.321s
# prediction time : 0.416s

# %% [markdown]
# Nous reproduisons le graphique f3 vs recall en prenant 10% des meilleures combinaisons (selon le f3), en fittant le modèle sur 10% des données.

# %%
"""%%time

df_small = pd.read_csv('data/df_train_prepro.csv').sample(frac=0.1)
datasets_df_small = datasets(df_small, verbose=False)
X_small = datasets_df_small['X']
y_small = datasets_df_small['y']

f3_list = []
recall_list = []
params_list = []

results_sort = results.sort_values(by='mean_test_f3', ascending=False)

nb_tot = int(0.10 * len(results))
nb = 25

random.seed(1)
sample = random.sample(list(range(nb_tot)), nb)
for j in trange(nb):
    i = sample[j]
    params = results_sort.iloc[i].params
    m = Modelisation(X_small, y_small, XGBClassifier(**params))
    params_list.append(params)
    f3_list.append(m.metrics_score['f3'])
    recall_list.append(m.metrics_score['recall'])

plt.figure(figsize=(14, 8))
plt.scatter(recall_list, f3_list, marker='o')
plt.xlabel('recall')
plt.ylabel('f3')
plt.show()"""
# Out:
# "%%time\n\ndf_small = pd.read_csv('data/df_train_prepro.csv').sample(frac=0.1)\ndatasets_df_small = datasets(df_small, verbose=False)\nX_small = datasets_df_small['X']\ny_small = datasets_df_small['y']\n\nf3_list = []\nrecall_list = []\nparams_list = []\n\nresults_sort = results.sort_values(by='mean_test_f3', ascending=False)\n\nnb_tot = int(0.10 * len(results))\nnb = 25\n\nrandom.seed(1)\nsample = random.sample(list(range(nb_tot)), nb)\nfor j in trange(nb):\n    i = sample[j]\n    params = results_sort.iloc[i].params\n    m = Modelisation(X_small, y_small, XGBClassifier(**params))\n    params_list.append(params)\n    f3_list.append(m.metrics_score['f3'])\n    recall_list.append(m.metrics_score['recall'])\n\nplt.figure(figsize=(14, 8))\nplt.scatter(recall_list, f3_list, marker='o')\nplt.xlabel('recall')\nplt.ylabel('f3')\nplt.show()"

# %% [markdown]
# **Test de paramètres**

# %%
params = {"colsample_bytree": 1.0, 
          "gamma": 1,
          "min_child_weight": 15,
          "scale_pos_weight": 16.5,
          "subsample": 0.8,
          "n_jobs": -1}

# %%
m = Modelisation(X, y, XGBClassifier(**params))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()
# Out:
# Export PDF : output/model_xgboost/15.pdf
# f1 : 0.2637
# f3 : 0.5466
# f5 : 0.6546
# recall : 0.7469
# negative predictive value : 0.9803
# precision : 0.1601
# roc_auc : 0.8352
# training time : 28.548s
# prediction time : 0.432s

# %% [markdown]
# ## 3. XGBoost avec oversampling
#
# ### 3.1. GridSearchCV avec RandomOverSampler

# %%
over = RandomOverSampler(random_state=1234)

pipeline = Pipeline_imb([('over', over),
                         ('model', XGBClassifier(booster='gbtree', objective='binary:logistic', n_jobs=1))
                         ])

cv_params = {
    "over__sampling_strategy": [0.1, 0.2, 0.4, 0.6, 0.8, 1],
    "model__n_estimators": [50, 100, 150, 200, 300],
    "model__max_depth": [2, 4, 6, 8, 10],
    "model__learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
    "model__gamma": [0.5, 1, 1.5, 2, 5],
    "model__min_child_weight": [1, 3, 5, 10],
    "model__subsample": [0.6, 0.8, 1.0],
    "model__colsample_bytree": [0.6, 0.8, 1.0],
    "model__scale_pos_weight": [1, 16.5]   # A typical value to consider: sum(negative instances) / sum(positive instances)
}

print(len(ParameterGrid(cv_params)))
# Out:
# 324000

# %%
# SearchCV(pipeline, cv_params, data_frac=0.02, random=True, n_iter=20000, random_state=1234, n_jobs=35)

# %%
dico, results = restauration_CV('RandomOver_XGBoost_CV_Randomized20000_324000_0.02')
# Out:
# model : Pipeline(steps=[('over', RandomOverSampler(random_state=1234)),
#                 ('model', XGBClassifier())])
# model_name : RandomOver_XGBoost
# type : RandomizedSearchCV
# len_grid : 324000
# n_iter : 20000
# columns_quant : default
# columns_cat : default
# drop : if_binary
# data_frac : 0.02
# n_jobs : 28
# temps : 1day, 2h, 22min, 25.096s
# params : {'over__sampling_strategy': [0.1, 0.2, 0.4, 0.6, 0.8, 1], 'model__n_estimators': [50, 100, 150, 200, 300], 'model__max_depth': [2, 4, 6, 8, 10], 'model__learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3], 'model__gamma': [0.5, 1, 1.5, 2, 5], 'model__min_child_weight': [1, 3, 5, 10], 'model__subsample': [0.6, 0.8, 1.0], 'model__colsample_bytree': [0.6, 0.8, 1.0], 'model__scale_pos_weight': [1, 16.5]}
# scoring : {'recall': 'recall', 'precision': 'precision', 'f1': 'f1', 'f3': make_scorer(fbeta_score, beta=3), 'f5': make_scorer(fbeta_score, beta=5)}

# %%
graph_2scores_CV(dico, results, 'recall', 'f1', s=0.2, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/16.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'f3', s=0.2, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/17.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'f5', s=0.2, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/18.pdf

# %%
graph_2scores_CV(dico, results, 'recall', 'precision', s=0.2, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/19.pdf

# %%
graph_3scores_CV(dico, results, 'recall', 'precision', 'f1', s=0.05, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/20.pdf

# %%
graph_3scores_CV(dico, results, 'f1', 'f3', 'f5', s=0.05, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/21.pdf

# %%
graph_param_CV(dico, results, ncols=2, height=3.5, width=6, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/22.pdf

# %%
best_params = best_score_CV(dico, results, 'f3')
# Out:
#        mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 4308        7.847867       1.04545         0.049696        0.005807
# 11769       5.990138      0.720782          0.04076        0.006916
# 8550       11.065783      0.778024         0.043706        0.000992
# 13656       9.722415      1.460954         0.052404        0.010724
# 12980       6.727296      1.058198         0.041998        0.008133
# 16417      12.077533      1.588702         0.065045        0.010081
# 19022      29.982296      4.208771         0.216113        0.032794
# 13305      10.847553      1.755199         0.048429        0.007784
# 6587        6.840682      1.153077         0.046548        0.008711
# 2756        5.938074       0.84727         0.038638        0.007206
#
#        param_over__sampling_strategy  param_model__subsample  \
# 4308                             1.0                     0.6
# 11769                            1.0                     1.0
# 8550                             1.0                     0.6
# 13656                            1.0                     0.6
# 12980                            1.0                     0.6
# 16417                            1.0                     0.8
# 19022                            0.1                     0.6
# 13305                            1.0                     1.0
# 6587                             1.0                     1.0
# 2756                             1.0                     0.6
#
#        param_model__scale_pos_weight  param_model__n_estimators  \
# 4308                             1.0                        100
# 11769                            1.0                        100
# 8550                             1.0                        150
# 13656                            1.0                        150
# 12980                            1.0                        100
# 16417                            1.0                        200
# 19022                           16.5                        300
# 13305                            1.0                        150
# 6587                             1.0                        100
# 2756                             1.0                         50
#
#        param_model__min_child_weight  param_model__max_depth  ...  \
# 4308                              10                       2  ...
# 11769                              1                       2  ...
# 8550                               3                       2  ...
# 13656                             10                       2  ...
# 12980                              3                       2  ...
# 16417                              5                       2  ...
# 19022                             10                       6  ...
# 13305                              1                       2  ...
# 6587                              10                       2  ...
# 2756                               3                       2  ...
#
#        rank_test_precision  mean_test_f1  std_test_f1 rank_test_f1  \
# 4308                 10863      0.269877      0.00828         7953
# 11769                11098      0.266156     0.009315         8521
# 8550                 11028      0.267042     0.006827         8400
# 13656                11038      0.266768      0.00741         8447
# 12980                10922      0.268665     0.006554         8143
# 16417                10965       0.26801     0.009559         8236
# 19022                12322      0.239878     0.002354        10941
# 13305                11099       0.26572     0.009509         8565
# 6587                 10989      0.267612     0.007959         8292
# 2756                 11149       0.26483     0.007984         8669
#
#        mean_test_f3  std_test_f3  rank_test_f3  mean_test_f5  std_test_f5  \
# 4308       0.542528     0.014196             1      0.642388     0.015989
# 11769      0.541863     0.014041             2      0.644623     0.014742
# 8550       0.540458     0.010654             3      0.641525     0.011494
# 13656      0.539518     0.012015             4       0.64024     0.013167
# 12980      0.539374     0.011007             5      0.638336     0.012257
# 16417      0.539058     0.014966             6      0.638423     0.016322
# 19022      0.539055      0.00361             7      0.667056     0.004129
# 13305      0.538863     0.013529             8      0.640139     0.013894
# 6587       0.538744     0.011409             9      0.638253     0.011754
# 2756       0.538634     0.013818            10      0.640537     0.015688
#
#        rank_test_f5
# 4308           4655
# 11769          4474
# 8550           4743
# 13656          4863
# 12980          5044
# 16417          5034
# 19022          1548
# 13305          4880
# 6587           5056
# 2756           4822
#
# [10 rows x 29 columns]
# Meilleure combinaison de paramètres pour f3 :
# {'over__sampling_strategy': 1,
#  'model__subsample': 0.6,
#  'model__scale_pos_weight': 1,
#  'model__n_estimators': 100,
#  'model__min_child_weight': 10,
#  'model__max_depth': 2,
#  'model__learning_rate': 0.2,
#  'model__gamma': 2,
#  'model__colsample_bytree': 0.6}

# %%
best_params['model__booster'] = 'gbtree'
best_params['model__objective'] = 'binary:logistic'
best_params['model__n_jobs'] = -1
best_params['model__n_estimators'] = 100
PARAMS[dico['model_name']] = best_params

# %%
m = Modelisation(X, y, pipeline.set_params(**best_params))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()

metrics = m.metrics_score
metrics['model_name'] = dico['model_name']
metrics['training_time'] = m.training_time
metrics['prediction_time'] = m.prediction_time
SCORES.append(metrics)
# Out:
# Export PDF : output/model_xgboost/23.pdf
# f1 : 0.2655
# f3 : 0.5455
# f5 : 0.6511
# recall : 0.7408
# negative predictive value : 0.9800
# precision : 0.1617
# roc_auc : 0.8346
# training time : 41.855s
# prediction time : 0.43s

# %% [markdown]
# ### 3.2. GridSearchCV avec SMOTENC

# %% [markdown]
# ### 3.3. Comparaison

# %%
dr1 = restauration_CV('XGBoost_CV_Randomized10000_54000_0.02', verbose=False)
dr2 = restauration_CV('RandomOver_XGBoost_CV_Randomized20000_324000_0.02', verbose=False)

# %%
graph_2scores_CV_comp([dr2, dr1], 'recall', 'f3', s=[0.5, 1], alpha=0.3)

# %%
graph_2scores_CV_comp([dr2, dr1], 'recall', 'precision', s=[1, 2], alpha=0.3)

# %% [markdown]
# ## 4. XGBoost avec RFECV
# ### 4.1. Sans oversampling

# %%
with open("backups/RFECV_XGBoost.json", 'r') as f:
    export = json.load(f)
    columns_quant_RFECV = export['columns_quant']
    columns_cat_RFECV = export['columns_cat']

# %%
model = XGBClassifier(booster='gbtree', objective='binary:logistic', n_jobs=1)

cv_params = {
    "n_estimators": [50, 100, 150, 200, 300],
    "max_depth": [2, 4, 6, 8, 10],
    "learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
    "gamma": [0.5, 1, 1.5, 2, 5],
    "min_child_weight": [1, 3, 5, 10],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
    "scale_pos_weight": [1, 16.5]   # A typical value to consider: sum(negative instances) / sum(positive instances)
}

print(len(ParameterGrid(cv_params)))
# Out:
# 54000

# %%
# SearchCV(model, cv_params, columns_quant=columns_quant_RFECV, columns_cat=columns_cat_RFECV, data_frac=0.02, random=True, n_iter=10000, random_state=1234, n_jobs=35, name='RFECV')

# %%
dico, results = restauration_CV('XGBoost_RFECV_CV_Randomized10000_54000_0.02')
# Out:
# model : XGBClassifier()
# model_name : XGBoost_RFECV
# type : RandomizedSearchCV
# len_grid : 54000
# n_iter : 10000
# columns_quant : ['campaignctrlast24h', 'contextid', 'nbdayssincelastclick', 'nbdisplay_1hour', 'zonecostineuro']
# columns_cat : ['device_type_Android', 'device_type_Desktop', 'device_type_iPad', 'is_interstitial_True']
# drop : if_binary
# data_frac : 0.02
# n_jobs : 28
# temps : 2h, 27min, 9.478s
# params : {'n_estimators': [50, 100, 150, 200, 300], 'max_depth': [2, 4, 6, 8, 10], 'learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3], 'gamma': [0.5, 1, 1.5, 2, 5], 'min_child_weight': [1, 3, 5, 10], 'subsample': [0.6, 0.8, 1.0], 'colsample_bytree': [0.6, 0.8, 1.0], 'scale_pos_weight': [1, 16.5]}
# scoring : {'recall': 'recall', 'precision': 'precision', 'f1': 'f1', 'f3': make_scorer(fbeta_score, beta=3), 'f5': make_scorer(fbeta_score, beta=5)}

# %%
best_params = best_score_CV(dico, results, 'f3', display_table=False)
# Out:
# Meilleure combinaison de paramètres pour f3 :
# {'subsample': 1.0,
#  'scale_pos_weight': 16.5,
#  'n_estimators': 150,
#  'min_child_weight': 3,
#  'max_depth': 2,
#  'learning_rate': 0.1,
#  'gamma': 1.5,
#  'colsample_bytree': 0.6}

# %%
best_params['booster'] = 'gbtree'
best_params['objective'] = 'binary:logistic'
best_params['n_jobs'] = -1
best_params['n_estimators'] = 100
PARAMS[dico['model_name']] = best_params

# %%
datasets_df_RFECV = datasets(df, columns_quant=columns_quant_RFECV, columns_cat=columns_cat_RFECV)
X_RFECV = datasets_df_RFECV['X']
# Out:
# Columns_quant : ['campaignctrlast24h', 'contextid', 'nbdayssincelastclick', 'nbdisplay_1hour', 'zonecostineuro']
# Columns_cat : ['device_type_Android', 'device_type_Desktop', 'device_type_iPad', 'is_interstitial_True']
# drop : if_binary
#
# Nombre de variables pour X_quant : 5
# Index(['campaignctrlast24h', 'contextid', 'nbdayssincelastclick',
#        'nbdisplay_1hour', 'zonecostineuro'],
#       dtype='object')
# Nombre de variables pour X_cat : 4
# Index(['device_type_Android', 'device_type_Desktop', 'device_type_iPad',
#        'is_interstitial_True'],
#       dtype='object')
# Nombre de variables pour X : 9

# %%
m = Modelisation(X_RFECV, y, XGBClassifier(**best_params))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()

metrics = m.metrics_score
metrics['model_name'] = dico['model_name']
metrics['training_time'] = m.training_time
metrics['prediction_time'] = m.prediction_time
SCORES.append(metrics)
# Out:
# Export PDF : output/model_xgboost/24.pdf
# f1 : 0.2609
# f3 : 0.5376
# f5 : 0.6424
# recall : 0.7315
# negative predictive value : 0.9792
# precision : 0.1588
# roc_auc : 0.8275
# training time : 12.152s
# prediction time : 0.091s

# %% [markdown]
# ### 4.2. Avec oversampling (RandomOverSampler)

# %%
over = RandomOverSampler(random_state=1234)

pipeline = Pipeline_imb([('over', over),
                         ('model', XGBClassifier(booster='gbtree', objective='binary:logistic', n_jobs=1))
                         ])

cv_params = {
    "over__sampling_strategy": [0.1, 0.2, 0.4, 0.6, 0.8, 1],
    "model__n_estimators": [50, 100, 150, 200, 300],
    "model__max_depth": [2, 4, 6, 8, 10],
    "model__learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
    "model__gamma": [0.5, 1, 1.5, 2, 5],
    "model__min_child_weight": [1, 3, 5, 10],
    "model__subsample": [0.6, 0.8, 1.0],
    "model__colsample_bytree": [0.6, 0.8, 1.0],
    "model__scale_pos_weight": [1, 16.5]   # A typical value to consider: sum(negative instances) / sum(positive instances)
}

print(len(ParameterGrid(cv_params)))
# Out:
# 324000

# %%
# SearchCV(pipeline, cv_params, columns_quant=columns_quant_RFECV, columns_cat=columns_cat_RFECV, data_frac=0.02, random=True, n_iter=20000, random_state=1234, n_jobs=35, name='RFECV')

# %%
dico, results = restauration_CV('RandomOver_XGBoost_RFECV_CV_Randomized20000_324000_0.02')
# Out:
# model : Pipeline(steps=[('over', RandomOverSampler(random_state=1234)),
#                 ('model', XGBClassifier())])
# model_name : RandomOver_XGBoost_RFECV
# type : RandomizedSearchCV
# len_grid : 324000
# n_iter : 20000
# columns_quant : ['campaignctrlast24h', 'contextid', 'nbdayssincelastclick', 'nbdisplay_1hour', 'zonecostineuro']
# columns_cat : ['device_type_Android', 'device_type_Desktop', 'device_type_iPad', 'is_interstitial_True']
# drop : if_binary
# data_frac : 0.02
# n_jobs : 28
# temps : 7h, 5min, 28.895s
# params : {'over__sampling_strategy': [0.1, 0.2, 0.4, 0.6, 0.8, 1], 'model__n_estimators': [50, 100, 150, 200, 300], 'model__max_depth': [2, 4, 6, 8, 10], 'model__learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3], 'model__gamma': [0.5, 1, 1.5, 2, 5], 'model__min_child_weight': [1, 3, 5, 10], 'model__subsample': [0.6, 0.8, 1.0], 'model__colsample_bytree': [0.6, 0.8, 1.0], 'model__scale_pos_weight': [1, 16.5]}
# scoring : {'recall': 'recall', 'precision': 'precision', 'f1': 'f1', 'f3': make_scorer(fbeta_score, beta=3), 'f5': make_scorer(fbeta_score, beta=5)}

# %%
best_params = best_score_CV(dico, results, 'f3', display_table=False)
# Out:
# Meilleure combinaison de paramètres pour f3 :
# {'over__sampling_strategy': 1,
#  'model__subsample': 0.8,
#  'model__scale_pos_weight': 1,
#  'model__n_estimators': 100,
#  'model__min_child_weight': 5,
#  'model__max_depth': 2,
#  'model__learning_rate': 0.3,
#  'model__gamma': 2,
#  'model__colsample_bytree': 0.6}

# %%
best_params['model__booster'] = 'gbtree'
best_params['model__objective'] = 'binary:logistic'
best_params['model__n_jobs'] = -1
best_params['model__n_estimators'] = 100
PARAMS[dico['model_name']] = best_params

# %%
m = Modelisation(X_RFECV, y, pipeline.set_params(**best_params))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()

metrics = m.metrics_score
metrics['model_name'] = dico['model_name']
metrics['training_time'] = m.training_time
metrics['prediction_time'] = m.prediction_time
SCORES.append(metrics)
# Out:
# Export PDF : output/model_xgboost/25.pdf
# f1 : 0.2614
# f3 : 0.5400
# f5 : 0.6460
# recall : 0.7362
# negative predictive value : 0.9795
# precision : 0.1589
# roc_auc : 0.8300
# training time : 27.278s
# prediction time : 0.096s

# %% [markdown]
# ### 4.3. Avec oversampling (SMOTENC)

# %%
categorical_features = list(range(len(columns_quant_RFECV), len(columns_quant_RFECV) + len(columns_cat_RFECV)))
print(categorical_features)

over = SMOTENC(categorical_features=categorical_features,
               random_state=1234)

pipeline = Pipeline_imb([('over', over),
                         ('model', XGBClassifier(booster='gbtree', objective='binary:logistic', n_jobs=1))
                         ])

cv_params = {
    "over__sampling_strategy": [0.1, 0.2, 0.4, 0.6, 0.8, 1],
    "model__n_estimators": [50, 100, 150, 200, 300],
    "model__max_depth": [2, 4, 6, 8, 10],
    "model__learning_rate": [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3],
    "model__gamma": [0.5, 1, 1.5, 2, 5],
    "model__min_child_weight": [1, 3, 5, 10],
    "model__subsample": [0.6, 0.8, 1.0],
    "model__colsample_bytree": [0.6, 0.8, 1.0],
    "model__scale_pos_weight": [1, 16.5]   # A typical value to consider: sum(negative instances) / sum(positive instances)
}

print(len(ParameterGrid(cv_params)))
# Out:
# [5, 6, 7, 8]
# 324000

# %%
# SearchCV(pipeline, cv_params, columns_quant=columns_quant_RFECV, columns_cat=columns_cat_RFECV, data_frac=0.02, random=True, n_iter=20000, random_state=1234, n_jobs=35, name='RFECV')

# %%
dico, results = restauration_CV('SMOTENC_XGBoost_RFECV_CV_Randomized20000_324000_0.02')
# Out:
# model : Pipeline(steps=[('over',
#                  SMOTENC(categorical_features=[5, 6, 7, 8], random_state=1234)),
#                 ('model', XGBClassifier())])
# model_name : SMOTENC_XGBoost_RFECV
# type : RandomizedSearchCV
# len_grid : 324000
# n_iter : 20000
# columns_quant : ['campaignctrlast24h', 'contextid', 'nbdayssincelastclick', 'nbdisplay_1hour', 'zonecostineuro']
# columns_cat : ['device_type_Android', 'device_type_Desktop', 'device_type_iPad', 'is_interstitial_True']
# drop : if_binary
# data_frac : 0.02
# n_jobs : 35
# temps : 7h, 37.553s
# params : {'over__sampling_strategy': [0.1, 0.2, 0.4, 0.6, 0.8, 1], 'model__n_estimators': [50, 100, 150, 200, 300], 'model__max_depth': [2, 4, 6, 8, 10], 'model__learning_rate': [0.0001, 0.001, 0.01, 0.1, 0.2, 0.3], 'model__gamma': [0.5, 1, 1.5, 2, 5], 'model__min_child_weight': [1, 3, 5, 10], 'model__subsample': [0.6, 0.8, 1.0], 'model__colsample_bytree': [0.6, 0.8, 1.0], 'model__scale_pos_weight': [1, 16.5]}
# scoring : {'recall': 'recall', 'precision': 'precision', 'f1': 'f1', 'f3': make_scorer(fbeta_score, beta=3), 'f5': make_scorer(fbeta_score, beta=5)}

# %%
best_params = best_score_CV(dico, results, 'f3', display_table=False)
# Out:
# Meilleure combinaison de paramètres pour f3 :
# {'over__sampling_strategy': 0.1,
#  'model__subsample': 0.6,
#  'model__scale_pos_weight': 16.5,
#  'model__n_estimators': 150,
#  'model__min_child_weight': 5,
#  'model__max_depth': 2,
#  'model__learning_rate': 0.1,
#  'model__gamma': 1.5,
#  'model__colsample_bytree': 0.6}

# %%
best_params['over__n_jobs'] = -1
best_params['model__booster'] = 'gbtree'
best_params['model__objective'] = 'binary:logistic'
best_params['model__n_jobs'] = -1
best_params['model__n_estimators'] = 100
PARAMS[dico['model_name']] = best_params
with open("backups/PARAMS_XGBoost.json", 'w') as f:
    json.dump(PARAMS, f, indent=2)

# %%
m = Modelisation(X_RFECV, y, pipeline.set_params(**best_params))
m.show_conf_matrix(pdf=pdf)
m.show_metrics_score()

metrics = m.metrics_score
metrics['model_name'] = dico['model_name']
metrics['training_time'] = m.training_time
metrics['prediction_time'] = m.prediction_time
SCORES.append(metrics)
# Out:
# Export PDF : output/model_xgboost/26.pdf
# f1 : 0.2083
# f3 : 0.5245
# f5 : 0.6843
# recall : 0.8452
# negative predictive value : 0.9851
# precision : 0.1188
# roc_auc : 0.8262
# training time : 4min, 42.82s
# prediction time : 0.091s

# %% [markdown]
# ### 4.4. Comparaison

# %%
dr1 = restauration_CV('XGBoost_CV_Randomized10000_54000_0.02', verbose=False)
dr2 = restauration_CV('XGBoost_RFECV_CV_Randomized10000_54000_0.02', verbose=False)
dr3 = restauration_CV('RandomOver_XGBoost_CV_Randomized20000_324000_0.02', verbose=False)
dr4 = restauration_CV('RandomOver_XGBoost_RFECV_CV_Randomized20000_324000_0.02', verbose=False)
dr5 = restauration_CV('SMOTENC_XGBoost_RFECV_CV_Randomized20000_324000_0.02', verbose=False)

# %%
graph_2scores_CV_comp([dr1, dr2], 'recall', 'f3', s=[1, 1], alpha=0.3, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/27.pdf

# %%
graph_2scores_CV_comp([dr1, dr2], 'recall', 'precision', s=[2, 2], alpha=0.3, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/28.pdf

# %%
graph_2scores_CV_comp([dr3, dr4], 'recall', 'f3', s=[0.5, 0.5], alpha=0.3, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/29.pdf

# %%
graph_2scores_CV_comp([dr3, dr4], 'recall', 'precision', s=[1, 1], alpha=0.3, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/30.pdf

# %%
graph_2scores_CV_comp([dr5, dr4, dr2], 'recall', 'f3', s=[0.5, 0.5, 0.5], alpha=0.3, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/31.pdf

# %%
graph_2scores_CV_comp([dr5, dr4, dr2], 'recall', 'precision', s=[1, 1, 1], alpha=0.3, pdf=pdf)
# Out:
# Export PDF : output/model_xgboost/32.pdf

# %% [markdown]
# ## 5. Bilan

# %%
scores_df = pd.DataFrame(SCORES).set_index('model_name')
a = scores_df.columns.tolist()
a.remove('training_time')
a.remove('prediction_time')
scores_df.sort_values(by='f3', ascending=False).to_csv('backups/SCORES_XGBoost.csv')
scores_df.sort_values(by='f3', ascending=False).style.background_gradient(cmap='Blues', subset=a).background_gradient(cmap='Blues_r', subset=['training_time', 'prediction_time'])
# Out:
# <style  type="text/css" >
# #T_d257d_row0_col0,#T_d257d_row0_col1,#T_d257d_row0_col5,#T_d257d_row0_col6,#T_d257d_row1_col6,#T_d257d_row3_col7,#T_d257d_row3_col8,#T_d257d_row4_col2,#T_d257d_row4_col3,#T_d257d_row4_col4,#T_d257d_row4_col8{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_d257d_row0_col2{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_d257d_row0_col3{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_d257d_row0_col4{
#             background-color:  #dfecf7;
#             color:  #000000;
#         }#T_d257d_row0_col7,#T_d257d_row1_col0,#T_d257d_row1_col1,#T_d257d_row1_col5{
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }#T_d257d_row0_col8,#T_d257d_row2_col3{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_d257d_row1_col2{
#             background-color:  #cee0f2;
#             color:  #000000;
#         }#T_d257d_row1_col3{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_d257d_row1_col4{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_d257d_row1_col7{
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }#T_d257d_row1_col8,#T_d257d_row3_col2,#T_d257d_row3_col3,#T_d257d_row3_col4,#T_d257d_row4_col0,#T_d257d_row4_col1,#T_d257d_row4_col5,#T_d257d_row4_col6,#T_d257d_row4_col7{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_d257d_row2_col0{
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }#T_d257d_row2_col1{
#             background-color:  #2777b8;
#             color:  #000000;
#         }#T_d257d_row2_col2{
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }#T_d257d_row2_col4{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_d257d_row2_col5{
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }#T_d257d_row2_col6{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_d257d_row2_col7{
#             background-color:  #083e81;
#             color:  #f1f1f1;
#         }#T_d257d_row2_col8{
#             background-color:  #083471;
#             color:  #f1f1f1;
#         }#T_d257d_row3_col0{
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }#T_d257d_row3_col1{
#             background-color:  #4695c8;
#             color:  #000000;
#         }#T_d257d_row3_col5{
#             background-color:  #08478d;
#             color:  #f1f1f1;
#         }#T_d257d_row3_col6{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }</style><table id="T_d257d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >f1</th>        <th class="col_heading level0 col1" >f3</th>        <th class="col_heading level0 col2" >f5</th>        <th class="col_heading level0 col3" >recall</th>        <th class="col_heading level0 col4" >negative predictive value</th>        <th class="col_heading level0 col5" >precision</th>        <th class="col_heading level0 col6" >roc_auc</th>        <th class="col_heading level0 col7" >training_time</th>        <th class="col_heading level0 col8" >prediction_time</th>    </tr>    <tr>        <th class="index_name level0" >model_name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d257d_level0_row0" class="row_heading level0 row0" >XGBoost</th>
#                         <td id="T_d257d_row0_col0" class="data row0 col0" >0.266680</td>
#                         <td id="T_d257d_row0_col1" class="data row0 col1" >0.545934</td>
#                         <td id="T_d257d_row0_col2" class="data row0 col2" >0.650773</td>
#                         <td id="T_d257d_row0_col3" class="data row0 col3" >0.739534</td>
#                         <td id="T_d257d_row0_col4" class="data row0 col4" >0.979935</td>
#                         <td id="T_d257d_row0_col5" class="data row0 col5" >0.162670</td>
#                         <td id="T_d257d_row0_col6" class="data row0 col6" >0.834623</td>
#                         <td id="T_d257d_row0_col7" class="data row0 col7" >18.321119</td>
#                         <td id="T_d257d_row0_col8" class="data row0 col8" >0.415714</td>
#             </tr>
#             <tr>
#                         <th id="T_d257d_level0_row1" class="row_heading level0 row1" >RandomOver_XGBoost</th>
#                         <td id="T_d257d_row1_col0" class="data row1 col0" >0.265462</td>
#                         <td id="T_d257d_row1_col1" class="data row1 col1" >0.545455</td>
#                         <td id="T_d257d_row1_col2" class="data row1 col2" >0.651110</td>
#                         <td id="T_d257d_row1_col3" class="data row1 col3" >0.740791</td>
#                         <td id="T_d257d_row1_col4" class="data row1 col4" >0.979978</td>
#                         <td id="T_d257d_row1_col5" class="data row1 col5" >0.161704</td>
#                         <td id="T_d257d_row1_col6" class="data row1 col6" >0.834628</td>
#                         <td id="T_d257d_row1_col7" class="data row1 col7" >41.854580</td>
#                         <td id="T_d257d_row1_col8" class="data row1 col8" >0.429820</td>
#             </tr>
#             <tr>
#                         <th id="T_d257d_level0_row2" class="row_heading level0 row2" >RandomOver_XGBoost_RFECV</th>
#                         <td id="T_d257d_row2_col0" class="data row2 col0" >0.261426</td>
#                         <td id="T_d257d_row2_col1" class="data row2 col1" >0.540045</td>
#                         <td id="T_d257d_row2_col2" class="data row2 col2" >0.645960</td>
#                         <td id="T_d257d_row2_col3" class="data row2 col3" >0.736201</td>
#                         <td id="T_d257d_row2_col4" class="data row2 col4" >0.979542</td>
#                         <td id="T_d257d_row2_col5" class="data row2 col5" >0.158931</td>
#                         <td id="T_d257d_row2_col6" class="data row2 col6" >0.829962</td>
#                         <td id="T_d257d_row2_col7" class="data row2 col7" >27.278311</td>
#                         <td id="T_d257d_row2_col8" class="data row2 col8" >0.096108</td>
#             </tr>
#             <tr>
#                         <th id="T_d257d_level0_row3" class="row_heading level0 row3" >XGBoost_RFECV</th>
#                         <td id="T_d257d_row3_col0" class="data row3 col0" >0.260942</td>
#                         <td id="T_d257d_row3_col1" class="data row3 col1" >0.537606</td>
#                         <td id="T_d257d_row3_col2" class="data row3 col2" >0.642391</td>
#                         <td id="T_d257d_row3_col3" class="data row3 col3" >0.731501</td>
#                         <td id="T_d257d_row3_col4" class="data row3 col4" >0.979219</td>
#                         <td id="T_d257d_row3_col5" class="data row3 col5" >0.158793</td>
#                         <td id="T_d257d_row3_col6" class="data row3 col6" >0.827544</td>
#                         <td id="T_d257d_row3_col7" class="data row3 col7" >12.151782</td>
#                         <td id="T_d257d_row3_col8" class="data row3 col8" >0.091117</td>
#             </tr>
#             <tr>
#                         <th id="T_d257d_level0_row4" class="row_heading level0 row4" >SMOTENC_XGBoost_RFECV</th>
#                         <td id="T_d257d_row4_col0" class="data row4 col0" >0.208286</td>
#                         <td id="T_d257d_row4_col1" class="data row4 col1" >0.524465</td>
#                         <td id="T_d257d_row4_col2" class="data row4 col2" >0.684268</td>
#                         <td id="T_d257d_row4_col3" class="data row4 col3" >0.845229</td>
#                         <td id="T_d

# %%
print(f"Temps d'exécution total : {time.strftime('%H:%M:%S', time.gmtime(time.time()-t))}")
# Out:
# Temps d'exécution total : 00:10:43

# %%
import os
os.chdir(os.path.dirname(os.getcwd()))
import json
import time

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
from kneed import KneeLocator
from scipy.sparse import csr_matrix
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE, RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier

from tools import COLUMNS_CAT, COLUMNS_QUANT, datasets, PDF

pd.options.display.max_rows = 80

f3_scorer = metrics.make_scorer(metrics.fbeta_score, beta=3)
f5_scorer = metrics.make_scorer(metrics.fbeta_score, beta=5)

pdf = PDF('output/rfecv/')

t = time.time()

# %%
df = pd.read_csv('data/df_train_prepro.csv').sample(frac=1, random_state=1234)
df.shape
# Out:
# (1610494, 48)

# %% [markdown]
# ## 1. Régression logistique
#
# Pour la régression logistique, on enlève les premières colonnes pour les variables indicatrices.

# %%
datasets_df = datasets(df, drop='first')
X_quant_scaled = datasets_df['X_quant_scaled']
X_only_quant_scaled = datasets_df['X_only_quant_scaled']
y = datasets_df['y']
# Out:
# Columns_quant : default
# Columns_cat : default
# drop : first
#
# Nombre de variables pour X_quant : 13
# Index(['contextid', 'campaignctrlast24h', 'dayssincelastvisitdouble',
#        'ltf_nbglobaldisplay_4w', 'ltf_nbpartnerdisplayssincelastclick',
#        'ltf_nbpartnerdisplay_90d', 'ltf_nbpartnerclick_90d',
#        'ltf_nbpartnersales_90d', 'nbdayssincelastclick', 'nbdisplay_1hour',
#        'nbdisplayglobalapprox_1d_sum_xdevice', 'display_size',
#        'zonecostineuro'],
#       dtype='object')
# Nombre de variables pour X_cat : 50
# Index(['display_env_app_ios', 'display_env_other', 'display_env_web',
#        'target_env_2', 'campaignscenario_5', 'campaignscenario_6',
#        'campaignscenario_11', 'campaignscenario_12', 'campaignscenario_13',
#        'campaignscenario_17', 'campaignvertical_20.0', 'campaignvertical_23.0',
#        'campaignvertical_129.0', 'campaignvertical_200002.0',
#        'is_interstitial_True', 'device_type_Desktop',
#        'device_type_Desktop - Safari', 'device_type_Mobile - Other',
#        'device_type_Unknown', 'device_type_iPad', 'device_type_iPhone',
#        'hour_1', 'hour_2', 'hour_3', 'hour_4', 'hour_5', 'hour_6', 'hour_7',
#        'hour_8', 'hour_9', 'hour_10', 'hour_11', 'hour_12', 'hour_13',
#        'hour_14', 'hour_15', 'hour_16', 'hour_17', 'hour_18', 'hour_19',
#        'hour_20', 'hour_21', 'hour_22', 'hour_23', 'weekday_Monday',
#        'weekday_Saturday', 'weekday_Sunday', 'weekday_Thursday',
#        'weekday_Tuesday', 'weekday_Wednesday'],
#       dtype='object')
# Nombre de variables pour X : 63

# %% [markdown]
# ### 1.1. Méthode RFE

# %%
def run_RFE(model, n_features_to_select, X, y, export=None, sparse=False):
    # create the RFE model and select 3 attributes
    rfe = RFE(model, n_features_to_select=n_features_to_select)    
    if sparse:
        X_sparse = csr_matrix(X)
    else:
        X_sparse = X
    rfe = rfe.fit(X_sparse, y)

    # summarize the selection of the attributes
    #  print(rfe.support_)
    #  print(rfe.ranking_)
    
    dico = {"Rank": rfe.ranking_,
            "Support": rfe.support_}
    rf_df = pd.DataFrame(dico, index=X.columns).sort_values(by='Rank', ascending=True)

    display(rf_df)
    
    support = rf_df[rf_df.Support == True].index.to_list()
    
    columns_quant = sorted(list(set(support).intersection(set(COLUMNS_QUANT))))    
    columns_cat = sorted(list(set(support).difference(set(COLUMNS_QUANT))))
    
    print("Columns_quant :")
    display(columns_quant)
    print("\nColumns_cat :")
    display(columns_cat)    
    
    if export:        
        dico_export = {'columns_quant': columns_quant,
                       'columns_cat': columns_cat}
        with open(f"backups/{export}.json", 'w') as f:
            json.dump(dico_export, f, indent=2)
        print(f"\nExportation : backups/{export}.json")

# %%
# %%time
model = LogisticRegression()
run_RFE(model, 8, X_quant_scaled, y)
# Out:
#                                       Rank  Support
# campaignctrlast24h                       1     True
# ltf_nbpartnerdisplayssincelastclick      1     True
# ltf_nbpartnerclick_90d                   1     True
# nbdayssincelastclick                     1     True
# nbdisplay_1hour                          1     True
# nbdisplayglobalapprox_1d_sum_xdevice     1     True
# display_size                             1     True
# zonecostineuro                           1     True
# dayssincelastvisitdouble                 2    False
# contextid                                3    False
# ltf_nbpartnerdisplay_90d                 4    False
# ltf_nbglobaldisplay_4w                   5    False
# ltf_nbpartnersales_90d                   6    False
# Columns_quant :
# ['campaignctrlast24h',
#  'display_size',
#  'ltf_nbpartnerclick_90d',
#  'ltf_nbpartnerdisplayssincelastclick',
#  'nbdayssincelastclick',
#  'nbdisplay_1hour',
#  'nbdisplayglobalapprox_1d_sum_xdevice',
#  'zonecostineuro']
# Columns_cat :
# []
# CPU times: user 3min 2s, sys: 8min 39s, total: 11min 42s
# Wall time: 14.7 s

# %%
# %%time
model = LogisticRegression()
run_RFE(model, 3, X_quant_scaled, y)
# Out:
#                                       Rank  Support
# campaignctrlast24h                       1     True
# display_size                             1     True
# zonecostineuro                           1     True
# nbdisplay_1hour                          2    False
# nbdayssincelastclick                     3    False
# nbdisplayglobalapprox_1d_sum_xdevice     4    False
# ltf_nbpartnerdisplayssincelastclick      5    False
# ltf_nbpartnerclick_90d                   6    False
# dayssincelastvisitdouble                 7    False
# contextid                                8    False
# ltf_nbpartnerdisplay_90d                 9    False
# ltf_nbglobaldisplay_4w                  10    False
# ltf_nbpartnersales_90d                  11    False
# Columns_quant :
# ['campaignctrlast24h', 'display_size', 'zonecostineuro']
# Columns_cat :
# []
# CPU times: user 4min 40s, sys: 14min 1s, total: 18min 42s
# Wall time: 24 s

# %% [markdown]
# Pour ne pas avoir à définir un nombre de features, nous allons utiliser une méthode de Cross Validation qui permettra de calculer le nombre de features optimal.

# %% [markdown]
# ### 1.2. Méthode RFECV

# %%
def run_RFECV(model, X, y, score=f3_scorer, min_features_to_select=1, n_jobs=-1, knee=False, sparse=False, pdf=pdf):
    rfecv = RFECV(estimator=model, step=1, cv=5,
                  scoring=score,
                  min_features_to_select=min_features_to_select,
                  n_jobs=n_jobs)
    if sparse:
        X_sparse = csr_matrix(X)
    else:
        X_sparse = X
    rfecv.fit(X_sparse, y)

    # Plot number of features VS. cross-validation scores
    plt.figure()
    plt.xlabel("Nombre de variables sélectionnées")
    if score == f3_scorer:
        plt.ylabel("Score F3 moyen")
    else:
        plt.ylabel(f"Score {str(score)} moyen")
    x = range(min_features_to_select, len(rfecv.grid_scores_) + min_features_to_select)
    y = rfecv.grid_scores_
    plt.plot(x, y)
    if type(knee) == bool and knee:
        kneedle = KneeLocator(x, y)
        plt.vlines(kneedle.knee, plt.ylim()[0], plt.ylim()[1], linestyles="--", linewidth=3, color='black', label="Coude")
    if type(knee) == int:
        plt.vlines(knee, plt.ylim()[0], plt.ylim()[1], linestyles="--", color='black', label="Coude")
    plt.grid()
    if pdf:
        pdf.export()
    plt.show()

    if type(knee) == bool and knee:
        print(f"Nombre optimal de variables à sélectionner (coude) : {kneedle.knee}")
        return kneedle.knee
    if type(knee) == int:
        print(f"Nombre optimal de variables à sélectionner (coude) : {knee}")
        return knee

# %% [markdown]
# #### 1.2.1. Variables quantitatives

# %%
# %%time
model = LogisticRegression()
knee = run_RFECV(model, X_quant_scaled, y, score=f3_scorer, knee=True)
# Out:
# Export PDF : output/rfecv/00.pdf
# Nombre optimal de variables à sélectionner (coude) : 4
# CPU times: user 1min 32s, sys: 4min 29s, total: 6min 2s
# Wall time: 37.3 s

# %% [markdown]
# Le nombre de features optimal semble être 4. Nous allons donc maintenant calculer une RFE avec cette valeur pour déterminer les features à conserver.

# %%
# %%time
model = LogisticRegression()
run_RFE(model, 4, X_quant_scaled, y)
# Out:
#                                       Rank  Support
# campaignctrlast24h                       1     True
# nbdisplay_1hour                          1     True
# display_size                             1     True
# zonecostineuro                           1     True
# nbdayssincelastclick                     2    False
# nbdisplayglobalapprox_1d_sum_xdevice     3    False
# ltf_nbpartnerdisplayssincelastclick      4    False
# ltf_nbpartnerclick_90d                   5    False
# dayssincelastvisitdouble                 6    False
# contextid                                7    False
# ltf_nbpartnerdisplay_90d                 8    False
# ltf_nbglobaldisplay_4w                   9    False
# ltf_nbpartnersales_90d                  10    False
# Columns_quant :
# ['campaignctrlast24h', 'display_size', 'nbdisplay_1hour', 'zonecostineuro']
# Columns_cat :
# []
# CPU times: user 4min 15s, sys: 12min 58s, total: 17min 13s
# Wall time: 22 s

# %% [markdown]
# #### 1.2.2. Variables quantitatives + catégorielles

# %% [markdown]
# Rajoutons à présent les variables catégorielles.

# %%
# %%time
model = LogisticRegression()
knee = run_RFECV(model, X_only_quant_scaled, y, score=f3_scorer, knee=11, sparse=True)
# Out:
# Export PDF : output/rfecv/01.pdf
# Nombre optimal de variables à sélectionner (coude) : 11
# CPU times: user 4min 1s, sys: 9.13 s, total: 4min 10s
# Wall time: 10min 12s

# %% [markdown]
# Le nombre de features optimal semble être 11. Nous allons donc maintenant calculer une RFE avec cette valeur pour déterminer les features à conserver.

# %%
# %%time
model = LogisticRegression()
run_RFE(model, 11, X_only_quant_scaled, y, export='RFECV_LR', sparse=True)
# Out:
#                                       Rank  Support
# zonecostineuro                           1     True
# device_type_Desktop                      1     True
# display_env_app_ios                      1     True
# display_size                             1     True
# nbdisplay_1hour                          1     True
# is_interstitial_True                     1     True
# nbdayssincelastclick                     1     True
# campaignscenario_13                      1     True
# device_type_iPhone                       1     True
# campaignctrlast24h                       1     True
# target_env_2                             1     True
# campaignvertical_200002.0                2    False
# device_type_Desktop - Safari             3    False
# nbdisplayglobalapprox_1d_sum_xdevice     4    False
# campaignscenario_12                      5    False
# dayssincelastvisitdouble                 6    False
# campaignscenario_5                       7    False
# contextid                                8    False
# campaignscenario_17                      9    False
# device_type_Mobile - Other              10    False
# campaignvertical_23.0                   11    False
# campaignscenario_6                      12    False
# display_env_web                         13    False
# ltf_nbpartnerdisplayssincelastclick     14    False
# ltf_nbpartnerclick_90d                  15    False
# campaignvertical_129.0                  16    False
# hour_18                                 17    False
# hour_11                                 18    False
# hour_16                                 19    False
# hour_17                                 20    False
# hour_12                                 21    False
# hour_15                                 22    False
# hour_10                                 23    False
# hour_20                                 24    False
# hour_13                                 25    False
# hour_9                                  26    False
# hour_14                                 27    False
# hour_19                                 28    False
# hour_8                                  29    False
# campaignscenario_11                     30    False
# campaignvertical_20.0                   31    False
# hour_21                                 32    False
# ltf_nbglobaldisplay_4w                  33    False
# ltf_nbpartnerdisplay_90d                34    False
# weekday_Tuesday                         35    False
# ltf_nbpartnersales_90d                  36    False
# weekday_Thursday                        37    False
# hour_2                                  38    False
# display_env_other                       39    False
# weekday_Monday                          40    False
# hour_23                                 41    False
# hour_3                                  42    False
# device_type_Unknown                     43    False
# weekday_Sunday                          44    False
# hour_6                                  45    False
# hour_7                                  46    False
# hour_4                                  47    False
# hour_5                                  48    False
# hour_22                                 49    False
# hour_1                                  50    False
# weekday_Wednesday                       51    False
# weekday_Saturday                        52    False
# device_type_iPad                        53    False
# Columns_quant :
# ['campaignctrlast24h',
#  'display_size',
#  'nbdayssincelastclick',
#  'nbdisplay_1hour',
#  'zonecostineuro']
# Columns_cat :
# ['campaignscenario_13',
#  'device_type_Desktop',
#  'device_type_iPhone',
#  'display_env_app_ios',
#  'is_interstitial_True',
#  'target_env_2']
# Exportation : backups/RFECV_LR.json
# CPU times: user 6min 10s, sys: 6.93 s, total: 6min 16s
# Wall time: 6min 16s

# %% [markdown]
# ## 2. Random Forest
#
# Pour les modèles de type arbre, il n'est pas nécessaire d'enlever toutes les premières colonnes des variables indicatrices.

# %%
datasets_df = datasets(df, drop='if_binary', verbose=False)
X = datasets_df['X']
y = datasets_df['y']

# %%
# %%time
model = RandomForestClassifier(n_jobs=10)
knee = run_RFECV(model, X, y, score=f3_scorer, n_jobs=5, knee=9)
# Out:
# Export PDF : output/rfecv/02.pdf
# Nombre optimal de variables à sélectionner (coude) : 9
# CPU times: user 9h 41min 26s, sys: 1min 59s, total: 9h 43min 25s
# Wall time: 3h 13min 42s

# %% [markdown]
# Le nombre de features optimal semble être 9. Nous allons donc maintenant calculer une RFE avec cette valeur pour déterminer les features à conserver.

# %%
# %%time
model = RandomForestClassifier(n_jobs=28)
run_RFE(model, 9, X, y, export='RFECV_Forest')
# Out:
#                                       Rank  Support
# contextid                                1     True
# campaignctrlast24h                       1     True
# dayssincelastvisitdouble                 1     True
# is_interstitial_True                     1     True
# nbdayssincelastclick                     1     True
# nbdisplay_1hour                          1     True
# nbdisplayglobalapprox_1d_sum_xdevice     1     True
# display_size                             1     True
# zonecostineuro                           1     True
# display_env_web                          2    False
# weekday_Monday                           3    False
# weekday_Thursday                         4    False
# weekday_Saturday                         5    False
# weekday_Wednesday                        6    False
# weekday_Sunday                           7    False
# campaignvertical_20.0                    8    False
# hour_19                                  9    False
# device_type_Android                     10    False
# weekday_Friday                          11    False
# weekday_Tuesday                         12    False
# hour_18                                 13    False
# hour_20                                 14    False
# hour_17                                 15    False
# hour_16                                 16    False
# campaignscenario_0                      17    False
# hour_15                                 18    False
# hour_14                                 19    False
# hour_12                                 20    False
# hour_13                                 21    False
# hour_11                                 22    False
# hour_7                                  23    False
# ltf_nbglobaldisplay_4w                  24    False
# hour_21                                 25    False
# hour_10                                 26    False
# hour_8                                  27    False
# hour_9                                  28    False
# display_env_app_android                 29    False
# target_env_2                            30    False
# hour_6                                  31    False
# campaignscenario_13                     32    False
# device_type_Desktop                     33    False
# hour_5                                  34    False
# device_type_iPhone                      35    False
# hour_22                                 36    False
# campaignvertical_14.0                   37    False
# ltf_nbpartnerdisplay_90d                38    False
# campaignscenario_12                     39    False
# campaignvertical_129.0                  40    False
# display_env_app_ios                     41    False
# hour_4                                  42    False
# device_type_Unknown                     43    False
# device_type_iPad                        44    False
# ltf_nbpartnerclick_90d                  45    False
# hour_23                                 46    False
# campaignscenario_6                      47    False
# campaignscenario_11                     48    False
# campaignvertical_200002.0               49    False
# hour_3                                  50    False
# ltf_nbpartnerdisplayssincelastclick     51    False
# campaignscenario_17                     52    False
# hour_0                                  53    False
# device_type_Desktop - Safari            54    False
# hour_2                                  55    False
# hour_1                                  56    False
# campaignvertical_23.0                   57    False
# device_type_Mobile - Other              58    False
# campaignscenario_5                      59    False
# ltf_nbpartnersales_90d                  60    False
# display_env_other                       61    False
# Columns_quant :
# ['campaignctrlast24h',
#  'contextid',
#  'dayssincelastvisitdouble',
#  'display_size',
#  'nbdayssincelastclick',
#  'nbdisplay_1hour',
#  'nbdisplayglobalapprox_1d_sum_xdevice',
#  'zonecostineuro']
# Columns_cat :
# ['is_interstitial_True']
# Exportation : backups/RFECV_Forest.json
# CPU times: user 14h 53min 30s, sys: 4min 6s, total: 14h 57min 37s
# Wall time: 36min 23s

# %% [markdown]
# ## 3. XGBoost

# %%
# %%time
model = XGBClassifier(n_jobs=10)
knee = run_RFECV(model, X, y, score=f3_scorer, n_jobs=5, knee=True)
# Out:
# Export PDF : output/rfecv/03.pdf
# Nombre optimal de variables à sélectionner (coude) : 9
# CPU times: user 4h 2min 19s, sys: 54.4 s, total: 4h 3min 13s
# Wall time: 1h 12min 38s

# %%
# %%time
model = XGBClassifier(n_jobs=28)
run_RFE(model, 9, X, y, export='RFECV_XGBoost')
# Out:
#                                       Rank  Support
# contextid                                1     True
# campaignctrlast24h                       1     True
# is_interstitial_True                     1     True
# zonecostineuro                           1     True
# device_type_iPad                         1     True
# nbdisplay_1hour                          1     True
# device_type_Desktop                      1     True
# device_type_Android                      1     True
# nbdayssincelastclick                     1     True
# campaignvertical_23.0                    2    False
# campaignscenario_13                      3    False
# dayssincelastvisitdouble                 4    False
# display_env_app_android                  5    False
# nbdisplayglobalapprox_1d_sum_xdevice     6    False
# display_env_web                          7    False
# campaignscenario_6                       8    False
# campaignscenario_5                       9    False
# device_type_Unknown                     10    False
# display_size                            11    False
# campaignscenario_12                     12    False
# campaignscenario_17                     13    False
# campaignscenario_0                      14    False
# device_type_iPhone                      15    False
# target_env_2                            16    False
# campaignvertical_129.0                  17    False
# campaignvertical_200002.0               18    False
# campaignvertical_20.0                   19    False
# campaignscenario_11                     20    False
# device_type_Desktop - Safari            21    False
# campaignvertical_14.0                   22    False
# display_env_app_ios                     23    False
# ltf_nbpartnersales_90d                  24    False
# ltf_nbpartnerclick_90d                  25    False
# ltf_nbpartnerdisplay_90d                26    False
# ltf_nbpartnerdisplayssincelastclick     27    False
# ltf_nbglobaldisplay_4w                  28    False
# display_env_other                       29    False
# hour_0                                  30    False
# hour_1                                  31    False
# hour_2                                  32    False
# hour_3                                  33    False
# hour_4                                  34    False
# hour_5                                  35    False
# hour_6                                  36    False
# hour_7                                  37    False
# hour_8                                  38    False
# hour_9                                  39    False
# hour_10                                 40    False
# hour_11                                 41    False
# hour_12                                 42    False
# hour_13                                 43    False
# hour_14                                 44    False
# hour_15                                 45    False
# hour_16                                 46    False
# hour_17                                 47    False
# hour_18                                 48    False
# hour_19                                 49    False
# hour_20                                 50    False
# hour_21                                 51    False
# hour_22                                 52    False
# hour_23                                 53    False
# weekday_Friday                          54    False
# weekday_Monday                          55    False
# weekday_Saturday                        56    False
# weekday_Sunday                          57    False
# weekday_Thursday                        58    False
# weekday_Tuesday                         59    False
# weekday_Wednesday                       60    False
# device_type_Mobile - Other              61    False
# Columns_quant :
# ['campaignctrlast24h',
#  'contextid',
#  'nbdayssincelastclick',
#  'nbdisplay_1hour',
#  'zonecostineuro']
# Columns_cat :
# ['device_type_Android',
#  'device_type_Desktop',
#  'device_type_iPad',
#  'is_interstitial_True']
# Exportation : backups/RFECV_XGBoost.json
# CPU times: user 6h 38min 50s, sys: 1min 5s, total: 6h 39min 56s
# Wall time: 22min 1s

# %%
print(f"Temps d'exécution total : {time.strftime('%H:%M:%S', time.gmtime(time.time()-t))}")
# Out:
# Temps d'exécution total : 05:43:44
